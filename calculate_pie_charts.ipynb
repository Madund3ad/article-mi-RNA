# %%
if (!requireNamespace("BiocManager", quietly = TRUE))
  install.packages("BiocManager")
BiocManager::install("ChIPpeakAnno")
BiocManager::install("ChIPseeker")
BiocManager::install("clusterProfiler")
library(GenomicFeatures)
library(ChIPpeakAnno)
library(ChIPseeker)
library(clusterProfiler)

# %%
download.file("http://anonymous@ftp.ensembl.org/pub/grch37/release-87/gtf/homo_sapiens/Homo_sapiens.GRCh37.87.gtf.gz", destfile="Homo_sapiens.GRCh37.87.gtf.gz", method='wget')

# %%
txdb_all_annotation <- makeTxDbFromGFF('Homo_sapiens.GRCh37.87.gtf.gz')
# Out:
# Import genomic features from the file as a GRanges object ...
# OK
#
# Prepare the 'metadata' data frame ...
# OK
#
# Make the TxDb object ...
# Warning message in .get_cds_IDX(mcols0$type, mcols0$phase):
# "The "phase" metadata column contains non-NA values for features of type
#   stop_codon. This information was ignored."
# OK

# %%
chip_list <- list(
  'AGO2 HepG2.bed',
  'AGO1 K562.bed',
  'AGO1  HepG2.bed'
)

for (chip in chip_list) {
  print('--------------------------------------------')
  print(chip)
  print('--------------------------------------------')
  peakAnno <- annotatePeak(chip, tssRegion=c(-3000, 3000), TxDb=txdb_all_annotation)
  print(peakAnno)
}
# Out:
# [1] "--------------------------------------------"
# [1] "AGO2 HepG2.bed"
# [1] "--------------------------------------------"
# >> loading peak file...				 2022-05-13 05:35:53 PM
# >> preparing features information...		 2022-05-13 05:35:53 PM
# >> identifying nearest features...		 2022-05-13 05:35:53 PM
# >> calculating distance from peak to TSS...	 2022-05-13 05:35:54 PM
# >> assigning genomic annotation...		 2022-05-13 05:35:54 PM
# >> assigning chromosome lengths			 2022-05-13 05:35:59 PM
# >> done...					 2022-05-13 05:35:59 PM
# Annotated peaks generated by ChIPseeker
# 46107/46107  peaks were annotated
# Genomic Annotation Summary:
#               Feature  Frequency
# 9    Promoter (<=1kb) 54.6771640
# 10   Promoter (1-2kb)  9.1981695
# 11   Promoter (2-3kb)  6.5803457
# 4              5' UTR  0.4185915
# 3              3' UTR  4.8669399
# 1            1st Exon  0.1518208
# 7          Other Exon  4.2856833
# 2          1st Intron  3.9907172
# 8        Other Intron  9.6731516
# ...
